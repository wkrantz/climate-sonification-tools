# %% [markdown]
# This notebook outlines a process for loading timeseries data and outputting it in a MIDI file as CC values that can then be used to control whatever you would like in a DAW or another music creation environment.

# %% [markdown]
# # Example 1: CSV to MIDI

# %% [markdown]
# In the simplest case, we will load a csv file containing measurements of atmospheric CO2 levels and write it out as a single channel of MIDI CC without worrying too much about handling the actual dates.

# %%
pwd
# Out:
# '/home/wk/data_sonification/all_we_can_save_project'

# %%
import pandas as pd
import numpy as np
from midiutil import MIDIFile

# %%
co2 = pd.read_csv('data/co2_mm_mlo.csv',  # downloaded from https://gml.noaa.gov/ccgg/trends/data.html
            header=41, #skip the header lines
            names = ['year','month','decimal_date','average','deseasonalized','ndays','sdev','unc'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 co2 = pd.read_csv('data/co2_mm_mlo.csv',  # downloaded from https://gml.noaa.gov/ccgg/trends/data.html
#       2             header=41, #skip the header lines
#       3             names = ['year','month','decimal_date','average','deseasonalized','ndays','sdev','unc'])
#
# File ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/co2_mm_mlo.csv'

# %%
co2
# Out:
#      year  month  decimal_date  average  deseasonalized  ndays  sdev   unc
# 0    1958      4     1958.2877   317.45          315.16     -1 -9.99 -0.99
# 1    1958      5     1958.3699   317.51          314.71     -1 -9.99 -0.99
# 2    1958      6     1958.4548   317.24          315.14     -1 -9.99 -0.99
# 3    1958      7     1958.5370   315.86          315.18     -1 -9.99 -0.99
# 4    1958      8     1958.6219   314.93          316.18     -1 -9.99 -0.99
# ..    ...    ...           ...      ...             ...    ...   ...   ...
# 783  2023      7     2023.5417   421.83          421.45     21  0.48  0.20
# 784  2023      8     2023.6250   419.68          421.57     21  0.45  0.19
# 785  2023      9     2023.7083   418.51          421.95     18  0.30  0.14
# 786  2023     10     2023.7917   418.82          422.10     27  0.47  0.17
# 787  2023     11     2023.8750   420.46          422.48     21  0.88  0.37
#
# [788 rows x 8 columns]

# %%
co2['average'].plot()
# Out:
# <Axes: >

# %% [markdown]
# Before writing out to MIDI, we want to normalize the file to be in the range of 0-127 that are supported in a MIDI CC signal.

# %%
def norm_midi(cc,norm_bottom, norm_top):
    mmin = np.min(cc)
    cc = (cc - mmin)
    mmax = np.max(cc)
    cc = cc / mmax
    cc = cc * (norm_top - norm_bottom)
    cc = cc + norm_bottom
    return cc

# %%
norm_bottom = 0
norm_top = 127
cc = norm_midi(co2['average'], norm_bottom, norm_top)

# %%
cc.plot()
# Out:
# <Axes: >

# %% [markdown]
# To write this data out as MIDI CC events, we use the MIDIUtil library, and specifically the addControllerEvent function.
#
#
# Documentation can be found here:
# https://midiutil.readthedocs.io/en/latest/class.html#midiutil.MidiFile.MIDIFile.addControllerEvent

# %%
mf = MIDIFile(1)      # make a new MIDIFile object with 1 track

mf.addTempo(track=0,  # add to the first track
           time=0,    # set the tempo starting at the beginning of the track
           tempo=80)  # set BPM

# %%
# need to decide how many beats each timestep in our data file should take
# with monthly data, if we want 1 year (12 timesteps) to last 1 bar (4 beats)
# each timestep should be 1/3 of a beat

tempo_mult = 0.333333

# iterate through each timestep in the file and write a value out to the MIDIFile object
for i, entry in enumerate(cc):
    
        mf.addControllerEvent(track=0, 
                              channel=0,                 # 0-15
                              time=i*tempo_mult,         # time (in beats, as a float) to write value
                              controller_number=20,      # The CC channel to write to, 0-127
                              parameter=int(entry))      # value to write, must be integer
        
# save to a midi file
with open(f'data/manua_loa_co2_{norm_bottom}_{norm_top}_{tempo_mult}.mid', 'wb') as f:
    mf.writeFile(f)

# %% [markdown]
# This midi file now has data on the MIDI CC #20 channel that should be usable in your DAW if you import the midi file. Keep in mind there are no actual NOTES save in the midi file, so it may initially appear blank.

# %% [markdown]
# # Example 2: Load NetCDF and merge with CSV timeseries

# %%
import xarray as xr

# %%
era5_temp = xr.open_dataset('data/era5_ts_nh.nc')

# %%
era5_temp.t2m.plot()

# %%
era5_temp = norm_midi(era5_temp, norm_bottom, norm_top)

# %%
era5_temp_df = era5_temp.to_pandas()

# %%
era5_temp_df['year'] = era5_temp_df.index.year
era5_temp_df['mean'] = era5_temp_df.index.month

# %%
merged_data_df = pd.merge(era5_temp_df, cc, on=['year','month'], how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_20050/398173873.py in ?()
# ----> 1 merged_data_df = pd.merge(era5_temp_df, cc, on=['year','month'], how='left')
#
# ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     140     copy: bool | None = None,
#     141     indicator: str | bool = False,
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
# --> 144     op = _MergeOperation(
#     145         left,
#     146         right,
#     147         how=how,
#
# ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     729         (
#     730             self.left_join_keys,
#     731             self.right_join_keys,
#     732             self.join_names,
# --> 733         ) = self._get_merge_keys()
#     734
#     735         # validate the merge keys dtypes. We may need to coerce
#     736         # to avoid incompatible dtypes
#
# ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1187                         # Then we're either Hashable or a wrong-length arraylike,
#    1188                         #  the latter of which will raise
#    1189                         rk = cast(Hashable, rk)
#    1190                         if rk is not None:
# -> 1191                             right_keys.append(right._get_label_or_level_values(rk))
#    1192                         else:
#    1193                             # work-around for merge_asof(right_index=True)
#    1194                             right_keys.append(right.index)
#
# ~/miniconda3/envs/sonification/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'year'

# %%
cc
# Out:
# 0        5.714260
# 1        5.782558
# 2        5.475217
# 3        3.904365
# 4        2.845747
#           ...
# 783    124.529892
# 784    122.082549
# 785    120.750739
# 786    121.103612
# 787    122.970422
# Name: average, Length: 788, dtype: float64
